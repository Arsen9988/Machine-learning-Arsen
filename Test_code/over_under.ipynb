# %%
import numpy as np
import matplotlib.pyplot as plt

np.random
samples = 100
X = np.random.uniform(-3, 3,(samples,1))
f = lambda x: x**2 + 0.5*x + 3 + np.random.randn(samples,1)
y = f(X)
plt.plot(X, y, ".")
